# %% [markdown]
# Choses importantes à noter en début de projet :
#
# <br> Tester les modèles avec et sans la variable energy star score ("ENERGYSTARScore") afin de voir si elle a un réel impact positif dans nos résultats de prédiction.
# <br> Attention aux data leakage, dans l'entrainement de nos modèles, ne pas mettre des variables que nous n'aurons pas à notre disposition.
# <br> Il faudra prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments **non destinés à l’habitation**. Il faudra donc faire attention à filtrer sur nos batiments non destinés à l'habitation.
# <br> Il y a donc deux scores à calculer, les emissions de CO2 (variable : TotalGHGEmissions) et la consommation totale d'énergie de batiments (variable : SiteEnergyUse(kBtu))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\doare\\Desktop\\IML_Projet_3'

# %%
pd.set_option('display.max_columns', 50)

# %%
# Création d'une fonction pour supprimer les valeurs manquantes par colonne
def supprimer_colonne_vide(data : pd.DataFrame , pourcentage_val_manquantes : float) -> pd.DataFrame:
    """
    Fonction pour supprimer des colonnes en spécifiant le pourcentage de valeurs manquantes dans la colonne
    """
    colonne_a_garder = []
    for colonne in data.columns:
        if data[colonne].isna().sum()/data.shape[0] <= pourcentage_val_manquantes:
            colonne_a_garder.append(colonne)
    return data[colonne_a_garder]

# Création fonction pour observer les valeurs manquantes par colonne
def pourcentage_val_manquantes(data : pd.DataFrame):
    """
    Fonction qui sort un DataFrame avec 3 colonnes, les variables, le pourcentage de valeurs manquantes par variable et le nombre de valeurs manquantes
    """
    dataframe = pd.DataFrame(columns=['Variable', 'Pourcentage_valeurs_manquantes','Valeurs_manquantes'])
    dataframe['Variable'] = data.columns
    val_manquantes = list()
    val_manquantes_pourcentage = list()
    for col in data.columns:
        val1 = data[col].isna().sum().sum()
        val2 = data[col].isna().sum()/data.shape[0]
        val_manquantes.append(val1)
        val_manquantes_pourcentage.append(val2)
    dataframe['Pourcentage_valeurs_manquantes'] = list(val_manquantes_pourcentage)
    dataframe['Valeurs_manquantes'] = list(val_manquantes)
        
    return dataframe.sort_values(by = 'Pourcentage_valeurs_manquantes', ascending = False)

# Création fonction pour observer sous forme de graphique en bar le % de valeurs manquantes par colonne
def plot_pourcentage_val_manquantes_par_variable(data: pd.DataFrame, sample=False):
    """
    Mettre un échantillon du jeu de données si le dataset est trop lourd
    Permet d'afficher le pourcentage de valeur manquantes/non manquantes par variable sous forme de graphique en bar
    """
    if sample:
        subdata = data.sample(frac=0.5)
    else:
        subdata = data
    sns.displot(data=subdata.isna().melt(value_name="missing"),y="variable",hue="missing",multiple="fill",aspect=3.25)
    plt.gcf().set_size_inches(20, 30)


#Remplacer valeur manquantes pas un string
def remplacer_valeurs_manquantes_string(data: pd.DataFrame, colonne: str, valeur: str) -> pd.DataFrame:
    """
    Renseigner le jeu de données ainsi que la colonne dans laquelle on veut remplacer les valeurs. Enfin, il faut écrire par quoi on veut remplacer les valeurs manquantes
    """
    data[colonne] = data[colonne].fillna(valeur)

# %%
df = pd.read_csv('2016_Building_Energy_Benchmarking.csv')
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# ...

# %%
#Filtrer sur les batiments non résidentiel
df_prep = df[df.BuildingType.str.contains('Nonresidential|SPS-District K-12', case=False)]
df_prep.shape
# Out:
# (1644, 46)

# %%
df_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1644 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    1644 non-null   int64
#  1   DataYear                         1644 non-null   int64
#  2   BuildingType                     1644 non-null   object
#  3   PrimaryPropertyType              1644 non-null   object
#  4   PropertyName                     1644 non-null   object
#  5   Address                          1644 non-null   object
#  6   City                             1644 non-null   object
#  7   State                            1644 non-null   object
#  8   ZipCode                          1628 non-null   float64
#  9   TaxParcelIdentificationNumber    1644 non-null   object
#  10  CouncilDistrictCode              1644 non-null   int64
#  11  Neighborhood                     1644 non-null   object
# ...

# %%
df_prep = supprimer_colonne_vide(df_prep, 0.75)
df_prep.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# ...

# %%
df_prep['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'SPS-District K-12',
#        'Nonresidential WA'], dtype=object)

# %% [markdown]
# ### Gestion du type des variables

# %%
df_prep['ZipCode'] = df_prep['ZipCode'].astype("category")
df_prep['OSEBuildingID'] = df_prep['OSEBuildingID'].astype("object")
df_prep['DataYear'] = df_prep['DataYear'].astype("object")
df_prep['CouncilDistrictCode'] = df_prep['CouncilDistrictCode'].astype("object")
df_prep['YearBuilt'] = df_prep['YearBuilt'].astype("object")
df_prep['Latitude'] = df_prep['Latitude'].astype("object")
df_prep['Longitude'] = df_prep['Longitude'].astype("object")

# %% [markdown]
# ### Gestion du type des outliers

# %%
df_prep.describe()
# Out:
#        NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# count        1642.000000     1644.000000      1.644000e+03
# mean            1.034105        4.144769      1.106277e+05
# std             0.552039        6.603893      1.865990e+05
# min             0.000000        0.000000      1.128500e+04
# 25%             1.000000        1.000000      2.939350e+04
# 50%             1.000000        2.000000      4.898850e+04
# 75%             1.000000        4.000000      1.030000e+05
# max             9.000000       99.000000      1.952220e+06
#
#        PropertyGFAParking  PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# count         1644.000000            1.644000e+03               1.638000e+03
# mean         12998.984185            9.762875e+04               9.052103e+04
# std          42483.530246            1.640849e+05               1.523614e+05
# min              0.000000            3.636000e+03               5.656000e+03
# ...

# %% [markdown]
# Nous pouvons voir que pour le maximum est bien au dessus du 3ème quartile, cela nous porte a croire qu'il y a des valeurs aberrantes ou bien seulement atypique, nous allons voir comment gérer cela.

# %% [markdown]
# Nos 8 premières colonnes quantitatives correspondantes à des variables que nous pourrons mettre dans notre modèle d'apprentissage mais les autres variables quantitatives sont des variables issus de relevés effectués, nous ne pourrons donc pas les inclure dans le modèle.

# %%
prep_colonne_quanti_modele = df_prep.describe().iloc[:,:8].columns

# %%
prep_colonne_quanti_modele
# Out:
# Index(['NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
#        'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ENERGYSTARScore'],
#       dtype='object')

# %%
df_boxplot = df_prep[prep_colonne_quanti_modele]
plt.figure(figsize=(15,15))
for i in df_boxplot.columns:
    plt.subplot(4,2, df_boxplot.columns.get_loc(i)+1)
    plt.title(i)
    sns.boxplot(data=df_boxplot,y=i)

# %% [markdown]
# En effet pour toutes nos variables nous pouvons voir qu'il y a des outliers sauf pour ENERGYSTRATScore qui est bien compris entre 0 et 100.
# <br>Nous allons essayer de voir sir les valeurs très élevé concerne toujours le même batiment (ce qui signifie que c'est une donnée atypique, ou bien juste une valeur très elevé sur la variable qui peut donc correspondre a une erreur de saisie).

# %%
df_prep.loc[df_prep['NumberofBuildings']==df_prep['NumberofBuildings'].max(),:]
# Out:
#     OSEBuildingID DataYear    BuildingType PrimaryPropertyType  \
# 170           276     2016  NonResidential            Hospital
#
#                   PropertyName       Address     City State  ZipCode  \
# 170  Harborview Medical Center  325 9th Ave.  Seattle    WA  98104.0
#
#     TaxParcelIdentificationNumber CouncilDistrictCode Neighborhood Latitude  \
# 170                    8590900220                   3         EAST   47.604
#
#     Longitude YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 170  -122.324      2000                9.0               8           1158691
#
#      PropertyGFAParking  PropertyGFABuilding(s)  \
# 170                   0                 1158691
#
#                           ListOfAllPropertyUseTypes  \
# 170  Hospital (General Medical & Surgical), Parking
#
#                     LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 170  Hospital (General Medical & Surgical)                  1350182.0
#
# ...

# %% [markdown]
# Ce batiment étant un campus universitaire, nous comprenons donc le fait que ces valeurs soit très elevé par rapport aux autres batiment.

# %%
df_prep.loc[df_prep['NumberofFloors']==df_prep['NumberofFloors'].max(),:]
# Out:
#      OSEBuildingID DataYear    BuildingType PrimaryPropertyType  \
# 1359         21611     2016  NonResidential    Worship Facility
#
#                         PropertyName                   Address     City State  \
# 1359  Seattle Chinese Baptist Church  5801 Beacon Avenue South  Seattle    WA
#
#       ZipCode TaxParcelIdentificationNumber CouncilDistrictCode  \
# 1359  98108.0                    2124049098                   2
#
#           Neighborhood Latitude Longitude YearBuilt  NumberofBuildings  \
# 1359  GREATER DUWAMISH  47.5507  -122.303      1977                1.0
#
#       NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 1359              99             21948                   0
#
#       PropertyGFABuilding(s) ListOfAllPropertyUseTypes LargestPropertyUseType  \
# 1359                   21948          Worship Facility       Worship Facility
#
#       LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# ...
